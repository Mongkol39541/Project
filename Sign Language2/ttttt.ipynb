# %%
import cv2
import matplotlib.pyplot as plt

# %%
frame = cv2.imread("MinSize/dicussion/cnn/another pose not in dataset.jpg")
frame = cv2.resize(frame[:, :, ::-1], (400, 300))
plt.imshow(frame)
plt.axis('off')
# Out:
# (-0.5, 399.5, 299.5, -0.5)

# %%
plt.imsave('MinSize/dicussion/cnn/another pose not in dataset.pdf', frame)
