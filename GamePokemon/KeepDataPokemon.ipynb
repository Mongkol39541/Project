# %%
import pandas as pd

df = pd.read_csv("Day1.csv")
df
# Out:
#                    Name Grade Element โอกาสได้รับ SSR เพิ่มขึ้น  \
# 0               เบย์ลีฟ    SR   Grass                        2%
# 1                ฮาซึโบ     R   Grass                        4%
# 2            ยูกิคาบูริ     R   Grass                        6%
# 3                คิโมริ     R   Grass                        8%
# 4              คุไซฮานะ     R   Grass                       10%
# 5              จิโคริตา     R   Grass                       12%
# 6           เมก้ายูกิโน    SP   Grass                       14%
# 7                 จูไคน    SR   Grass                       16%
# 8              จิโคริตา     R   Grass                       18%
# 9              คุไซฮานะ     R   Grass                       20%
# 10             คุไซฮานะ     R   Grass                       22%
# 11  ฟุชิกิบานะกิกะแมกซ์    SP   Grass                       24%
# 12             รุนปัปปา    SR   Grass                       26%
# 13                จูไคน    SR   Grass                       28%
# ...
