# %%
import pandas as pd

df = pd.read_csv("Day1.csv")
df
# Out:
#                   Name Grade Element โอกาสได้รับ SSR เพิ่มขึ้น  \
# 0            ลิซาร์ดอน    SR    Fire                        2%
# 1               อาชาโม     R    Fire                        4%
# 2            ลิซาร์ดอน    SR    Fire                        6%
# 3   เอสเบิร์นกิกะแมกซ์    SP    Fire                        0%
# 4               อาชาโม     R    Fire                        2%
# 5             มาฟ็อกซี    SR    Fire                        4%
# 6           ฮิโนอาราชิ     R    Fire                        6%
# 7           ฮิโนอาราชิ     R    Fire                        8%
# 8               อาชาโม     R    Fire                       10%
# 9               ฮิบานี     R    Fire                       12%
# 10           ฮิโตคาเงะ     R    Fire                       14%
# 11              ฮิบานี     R    Fire                       16%
# 12             แบ็กฟูน    SR    Fire                       18%
# 13           ฮิโตคาเงะ     R    Fire                       20%
# ...
